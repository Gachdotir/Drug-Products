# %%
import pandas as pd

# %%
drug_list = pd.read_excel('Drugs Shape.xlsx')

# %%
drug_list.head()
# Out:
#            GTIN                                        BrandLaName  \
# 0  6.260152e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 1  6.260158e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 2  6.260165e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 3  6.260155e+12  DEPOCORTINE   INJECTION, SUSPENSION PARENTERAL...
# 4  6.260165e+12             METHYLTESTOSTERONE   TABLET ORAL 25 mg
#
#                                            BrandName  NumberPack  \
# 0  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 1  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 2  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 3  دپوکورتین   سوسپانسیون تزریقی پرنترال 40 mg/1m...           1
# 4                 متیل تستوسترون    قرص خوراکی 25 mg         100
#
#                 Producer  IsBulk                 GenericName  \
# 0             البرز دارو   False  METHYLPREDNISOLONE ACETATE
# ...

# %%
df = pd.DataFrame(drug_list)

# %%
df.head()
# Out:
#            GTIN                                        BrandLaName  \
# 0  6.260152e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 1  6.260158e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 2  6.260165e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 3  6.260155e+12  DEPOCORTINE   INJECTION, SUSPENSION PARENTERAL...
# 4  6.260165e+12             METHYLTESTOSTERONE   TABLET ORAL 25 mg
#
#                                            BrandName  NumberPack  \
# 0  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 1  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 2  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 3  دپوکورتین   سوسپانسیون تزریقی پرنترال 40 mg/1m...           1
# 4                 متیل تستوسترون    قرص خوراکی 25 mg         100
#
#                 Producer  IsBulk                 GenericName  \
# 0             البرز دارو   False  METHYLPREDNISOLONE ACETATE
# ...

# %%
df['Shape'].unique()
# Out:
# array(['INJECTION, SUSPENSION PARENTERAL', 'TABLET ORAL',
#        'INJECTION PARENTERAL', 'SOLUTION, DROPS ORAL',
#        'INJECTION, SOLUTION PARENTERAL', 'GEL TOPICAL', 'GEL VAGINAL',
#        'TABLET VAGINAL', 'SUSPENSION ORAL', 'CREAM TOPICAL',
#        'SOLUTION IRRIGATION', 'POWDER ORAL',
#        'INJECTION, POWDER, FOR SOLUTION PARENTERAL',
#        'SOLUTION, DROPS OPHTHALMIC', 'SOLUTION, DROPS NASAL',
#        'SOLUTION TOPICAL', 'TABLET, CHEWABLE ORAL', 'CAPSULE ORAL',
#        'OINTMENT TOPICAL', 'MOUTHWASH DENTAL', 'SYRUP ORAL',
#        'AEROSOL, METERED RESPIRATORY', 'INHALANT RESPIRATORY',
#        'INJECTION INTRAVENOUS', 'INJECTION, SOLUTION INTRAVENOUS',
#        'INJECTION, POWDER, LYOPHILIZED, FOR SOLUTION PARENTERAL',
#        'TABLET, DELAYED RELEASE ORAL', 'LOTION TOPICAL',
#        'INJECTION, POWDER, FOR SUSPENSION, EXTENDED RELEASE PARENTERAL',
#        'CAPSULE, EXTENDED RELEASE ORAL', 'TABLET, FOR SOLUTION ORAL',
# ...

# %%
duplicate_rows = df[df.duplicated(subset='GenericName', keep=False)]

# %%
duplicate_rows
# Out:
#               GTIN                                        BrandLaName  \
# 0     6.260152e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 1     6.260158e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 2     6.260165e+12  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 3     6.260155e+12  DEPOCORTINE   INJECTION, SUSPENSION PARENTERAL...
# 5     6.260158e+12        PLADIC   INJECTION PARENTERAL 5 mg/1mL 2 mL
# ...            ...                                                ...
# 1520  6.260184e+12  MAGNESIUM SULFATE   INJECTION PARENTERAL 20 % ...
# 1522  6.260157e+12         ARYAFEN   CAPSULE ORAL 325 mg/40 mg/200 mg
# 1523  6.260154e+12          ACIFEN   CAPSULE ORAL 325 mg/40 mg/200 mg
# 1524  6.260171e+12         NOVAFEN   CAPSULE ORAL 325 mg/40 mg/200 mg
# 1525  6.260509e+12         MEGAFEN   CAPSULE ORAL 325 mg/40 mg/200 mg
#
#                                               BrandName  NumberPack  \
# ...

# %%
df['Dose'].unique()
# Out:
# array(['40 mg/1mL', '25 mg', '5 mg/1mL 2 mL', '4 mg/1mL 15 mL', '10 mg',
#        '1 mg/1mL 5 mL', '50 mg', '5 mg/1mL 100 mL', '250 mg',
#        '0.75 % 30 g', '0.75 % 70 g', '500 mg', '125 mg/5mL 120 mL',
#        '2 % 30 g', '5 mg/1mL 1 mL', '0.9 % 500 mL', '0.9 % 1000 mL',
#        '0.9 % 2 L', '0.9 % 3 L', '5 g', '80 mg', '100 mg', '1 g',
#        '20 mg/1mL 5 mL', '50 mg/1mL 10 mL', '5 ug/1mL 2 mL', '10 % 10 mL',
#        '7.5 % 50 mL', '0.45 % 500 mL', '5 % 50 mL', '0.65 % 20 mL',
#        '70 mg', '20 mg/1mL 60 mL', '50 mg/1mL 60 mL', '150 mg', '5 mg',
#        '10 mg/1mL',
#        '25000 [iU]/20 mg/5 mg/50 mg/10 mg/5 ug/150 mg/0.25 mg/1000 [iU]/10 mg/1 mg/11.6 mg/100 mg/5 mg/0.5 mg/0.1 mg/10 mg/0.5 mg/72.27 mg/1 mg',
#        '2 % 15 g', '0.2 % 250 mL', '20 mg', '4 mg/1mL 60 mL', '25 mg/1mL',
#        '250 ug/1{dose} 120 {Puff}', '50 ug/1{dose} 120 {Puff}',
#        '50 mg/15mL 120 mL', '10 mg/1mL 2 mL', '300 mg', '400 mg',
# ...

# %%
duplicate_rows['GenericName'].unique()
# Out:
# array(['METHYLPREDNISOLONE ACETATE', 'METOCLOPRAMIDE',
#        'METOCLOPRAMIDE HYDROCHLORIDE', 'METOPROLOL TARTRATE',
#        'METRONIDAZOLE', 'MICONAZOLE NITRATE', 'MIDAZOLAM',
#        'SODIUM CHLORIDE', 'SORBITOL', 'SOTALOL HYDROCHLORIDE',
#        'SPIRONOLACTONE', 'SUCCINYLCHOLINE CHLORIDE', 'SUCRALFATE',
#        'SUFENTANIL (AS CITRATE)', 'SULFACETAMIDE SODIUM',
#        'SUMATRIPTAN (AS SUCCINATE)', 'SILDENAFIL (AS CITRATE)',
#        'SODIUM BICARBONATE', 'ALENDRONATE SODIUM', 'MINOXIDIL',
#        'MONTELUKAST', 'MORPHINE SULFATE', 'MULTIVITAMIN THERAPEUTIC',
#        'MUPIROCIN', 'MYCOPHENOLATE MOFETIL',
#        'FLUOXETINE (AS HYDROCHLORIDE)', 'FLUTICASONE PROPIONATE',
#        'FLUVOXAMINE MALEATE', 'FOLIC ACID', 'FURAZOLIDONE', 'GABAPENTIN',
#        'GADOPENTETATE DIMEGLUMINE', 'GEMCITABINE (AS HYDROCHLORIDE)',
#        'GEMFIBROZIL', 'GENTAMICIN', 'GLIBENCLAMIDE', 'GLICLAZIDE',
#        'ARIPIPRAZOLE', 'LEVETIRACETAM', 'NICORANDIL', 'ESOMEPRAZOLE',
# ...

# %%
df[df['Dose']=='INJECTION, POWDER, LYOPHILIZED, FOR SUSPENSION PERCUTANEOUS']
# Out:
#               GTIN                                        BrandLaName  \
# 1132  6.260156e+12  BCG VACCINE   INJECTION, POWDER, LYOPHILIZED, ...
#
#                                               BrandName  NumberPack  \
# 1132  واکسن  ب ث ژ   پودر لئوفیلیزه برای تهیه سوسپان...           1
#
#                   Producer  IsBulk GenericName  \
# 1132  انستیتو پاستور ایران   False         BCG
#
#                                         FullGenericName  GenericCode    ATC  \
# 1132  BCG INJECTION, POWDER, LYOPHILIZED, FOR SUSPEN...         1403  J07AN
#
#      Condition  SellPrice  BuyPrice  \
# 1132      فعال          0       0.0
#
#                                                   Shape  \
# 1132  INJECTION, POWDER, LYOPHILIZED, FOR SUSPENSION...
#
#                                                    Dose
# 1132  INJECTION, POWDER, LYOPHILIZED, FOR SUSPENSION...
