# %%
import pandas as pd

# %%
drug_shape = pd.read_excel('Drugs Shape.xlsx')

# %%
drug_shape.head()
# Out:
#             GTIN                                        BrandLaName  \
# 0  6260152433031  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 1  6260157711400  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 2  6260164607277  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 3  6260155200067  DEPOCORTINE   INJECTION, SUSPENSION PARENTERAL...
# 4  6260164645446             METHYLTESTOSTERONE   TABLET ORAL 25 mg
#
#                                            BrandName  NumberPack  \
# 0  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 1  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 2  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 3  دپوکورتین   سوسپانسیون تزریقی پرنترال 40 mg/1m...           1
# 4                 متیل تستوسترون    قرص خوراکی 25 mg         100
#
#                 Producer  IsBulk                 GenericName  \
# 0             البرز دارو   False  METHYLPREDNISOLONE ACETATE
# ...

# %%
e_generic = drug_shape['GenericName'].unique()

# %%
e_generic
# Out:
# array(['METHYLPREDNISOLONE ACETATE', 'METHYLTESTOSTERONE',
#        'METOCLOPRAMIDE', 'METOCLOPRAMIDE HYDROCHLORIDE',
#        'METOPROLOL TARTRATE', 'METRONIDAZOLE', 'MICONAZOLE NITRATE',
#        'MIDAZOLAM', 'SODIUM CHLORIDE', 'SORBITOL',
#        'SOTALOL HYDROCHLORIDE', 'SPIRONOLACTONE',
#        'STREPTOMYCIN (AS SULFATE)', 'SUCCINYLCHOLINE CHLORIDE',
#        'SUCRALFATE', 'SUFENTANIL (AS CITRATE)', 'SULFACETAMIDE SODIUM',
#        'SUMATRIPTAN (AS SUCCINATE)', 'SILDENAFIL (AS CITRATE)',
#        'SODIUM BICARBONATE', 'ALENDRONATE SODIUM', 'MINOXIDIL',
#        'MOCLOBEMIDE', 'MONTELUKAST', 'MORPHINE SULFATE',
#        'MULTIVITAMIN THERAPEUTIC', 'MUPIROCIN', 'MYCOPHENOLATE MOFETIL',
#        'FLUORIDE SODIUM', 'FLUOROURACIL', 'FLUOXETINE (AS HYDROCHLORIDE)',
#        'FLUPHENAZINE DECANOATE', 'FLUTAMIDE', 'FLUTICASONE PROPIONATE',
#        'FLUVOXAMINE MALEATE', 'FOLIC ACID', 'FURAZOLIDONE', 'FUROSEMIDE',
# ...

# %%
en_generic = pd.DataFrame(e_generic)

# %%
en_generic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       473 non-null    object
# dtypes: object(1)
# memory usage: 3.8+ KB

# %%
en_generic
# Out:
#                                         0
# 0              METHYLPREDNISOLONE ACETATE
# 1                      METHYLTESTOSTERONE
# 2                          METOCLOPRAMIDE
# 3            METOCLOPRAMIDE HYDROCHLORIDE
# 4                     METOPROLOL TARTRATE
# ..                                    ...
# 468             PROPRANOLOL HYDROCHLORIDE
# 469     CHLORMADINONE / ETHINYL ESTRADIOL
# 470                    ADEFOVIR DIPIVOXIL
# 471                  METOPROLOL SUCCINATE
# 472  ACETAMINOPHEN / CAFFEINE / IBUPROFEN
#
# [473 rows x 1 columns]

# %%
e_generic[400:]
# Out:
# array(['ISOXSUPRINE HYDROCHLORIDE', 'ITRACONAZOLE', 'LACTULOSE',
#        'LAMIVUDINE', 'LAMOTRIGINE', 'LEVODOPA / CARBIDOPA',
#        'MEFENAMIC ACID', 'MEGESTROL ACETATE', 'ZINC OXIDE', 'WATER',
#        'PROMETHAZINE HYDROCHLORIDE', 'VERAPAMIL HYDROCHLORIDE',
#        'VITAMIN A', 'VITAMIN A / VITAMIN D', 'VITAMIN B COMPLEX',
#        'VITAMIN B12', 'VITAMIN B6', 'VITAMIN C', 'NALIDIXIC ACID',
#        'NALTREXONE HYDROCHLORIDE', 'NANDROLONE DECANOATE',
#        'NORTRIPTYLINE', 'ONDANSETRON', 'OXALIPLATIN', 'OXAZEPAM',
#        'OXYMETHOLONE', 'OXYTOCIN', 'POTASSIUM AMINOBENZOIC ACID (POTABA)',
#        'PANCREATIN', 'PANCURONIUM BROMIDE', 'PENICILLIN 6-3-3',
#        'PENICILLIN G PROCAINE', 'PENICILLIN G POTASSIUM', 'PENICILLIN V',
#        'PENICILLIN V POTASSIUM', 'PENTOXIFYLLINE',
#        'PERITONEAL DIALYSIS I', 'PHENYTOIN', 'PHENYTOIN / PHENOBARBITAL',
#        'PERITONEAL DIALYSIS III', 'PERPHENAZINE', 'PHENOBARBITAL',
# ...

# %%
f_generci =['استرات متیل پردنیزولون',
'متیل تستوسترون',
'متوکلوپرامید',
'هیدروکلرید متوکلوپرامید',
'تارترات متوپرولول',
'مترونیدازول',
'نیترات میکونازول',
'میدازولام',
'کلرید سدیم',
'سوربیتول',
'هیدروکلرید سوتالول',
'اسپایرونولاکتون',
'استرپتومایسین (به عنوان سولفات)',
'سوکسینیل کولین کلرید',
'ساکرالفات',
'سوفنتانیل (به عنوان سیترات)',
'سولفاستامید سدیم',
'سوماتریپتان (به عنوان سوکسینات)',
'سیلدنافیل (به عنوان سیترات)',
'بیکربنات سدیم',
'سدیم آلندرونات',
'مینوکسیدیل',
'موکلوبمید',
'مونتلوکست',
'سولفات مورفین',
'ترکیبات چندویتامین',
'موپیروسین',
'میکوفنولات موفتیل',
'فلوئورید سدیم',
'فلوروراسیل',
'فلوکستین (به عنوان هیدروکلراید)',
'دکانوات فلوفنازین',
'فلوتامید',
'پروپیونات فلوتیکازون',
'مالئات فلووکسامین',
'اسید فولیک',
'فورازولیدون',
'فوروسمید',
'گاباپنتین',
'دیمگلومین گادوپنتات',
'ژلاتین اصلاح‌شده',
'ژمسیتابین (به عنوان هیدروکلراید)',
'ژم‌فیبروزیل',
'ژنتامیسین',
'گلیبن‌کلاماید',
'گلیکلازید',
'آریپیپرازول',
'لووتیراستام',
'نیکوراندیل',
'ازمپرازول',
'سدیم ریزدرونات',
'مودافینیل',
'بوزنتان',
'لوودوپا/کاربیدوپا/انتاکاپون',
'فوروآت مومتازون',
'استرپتیدیل‌گلوتامیل‌لوپرولین',
'کلوتریمازول/بتامتازون (به عنوان دیپروپیونات)',
'کتوکونازول',
'ایمونوگلوبولین',
'نیتیزینون',
'ونلافاکسین',
'کتورولاک ترومتامول',
'رینجر لاکتات',
'ایبوپروفن',
'گلاتیرامر استات',
'متفرمین هیدروکلراید/گلیبن‌کلاماید',
'برومید ایپراتروپیوم/فنوترول هیدروبروماید',
'محصولات سرم‌زده بزرگسالان (۱-۲)',
'محصولات سرم‌زده بزرگسالان (۷-۱۰)',
'تموزولومید',
'لووفلوکساسین همی‌هیدرات',
'دیپروپیونات کلسیپوتریول/بتامتازون',
'اسید استامینوفن',
'سولیفناسین سوکسینات',
'دیالیز شکم‌شوکرانی IV بر اساس ایکودکسترین',
'دابیگاتران اتکسیلات (به عنوان مزیلات)',
'پرامی‌پکسول دیهیدروکلراید',
'آملودیپین (به عنوان بزیلات)/والسارتان',
'پراسوگرل',
'دولوکستین',
'تریپتورلین (به عنوان پاموآت)',
'ژمی‌فلوکساسین',
'اورولیموس',
'اکترئوتید (به عنوان استات)',
'هیدروکلراید سیپروهپتادین',
'فومارات کوئتیاپین',
'گرانی‌سِترون',
'منتول/اکسید روی/کلامین',
'هیدروکلراید آتوموکستین',
'سیناکالست (به عنوان هیدروکلراید)',
'توکسین بوتولینوم A',
'کمپلکس پروترومبین فعال (غلظت‌دار)',
'ایودیکسانول',
'ایوهگزول',
'پروپوفول',
'یوروفولیتروپین',
'دوسیتاکسل',
'سدیم والپروات',
'گادودیامید',
'لتروزول']

# %%
f_generci
# Out:
# ['استرات متیل پردنیزولون',
#  'متیل تستوسترون',
#  'متوکلوپرامید',
#  'هیدروکلرید متوکلوپرامید',
#  'تارترات متوپرولول',
#  'مترونیدازول',
#  'نیترات میکونازول',
#  'میدازولام',
#  'کلرید سدیم',
#  'سوربیتول',
#  'هیدروکلرید سوتالول',
#  'اسپایرونولاکتون',
#  'استرپتومایسین (به عنوان سولفات)',
#  'سوکسینیل کولین کلرید',
#  'ساکرالفات',
#  'سوفنتانیل (به عنوان سیترات)',
#  'سولفاستامید سدیم',
#  'سوماتریپتان (به عنوان سوکسینات)',
#  'سیلدنافیل (به عنوان سیترات)',
#  'بیکربنات سدیم',
#  'سدیم آلندرونات',
#  'مینوکسیدیل',
#  'موکلوبمید',
#  'مونتلوکست',
#  'سولفات مورفین',
#  'ترکیبات چندویتامین',
#  'موپیروسین',
#  'میکوفنولات موفتیل',
#  'فلوئورید سدیم',
#  'فلوروراسیل',
#  'فلوکستین (به عنوان هیدروکلراید)',
#  'دکانوات فلوفنازین',
#  'فلوتامید',
#  'پروپیونات فلوتیکازون',
#  'مالئات فلووکسامین',
#  'اسید فولیک',
#  'فورازولیدون',
#  'فوروسمید',
#  'گاباپنتین',
#  'دیمگلومین گادوپنتات',
#  'ژلاتین اصلاح\u200cشده',
#  'ژمسیتابین (به عنوان هیدروکلراید)',
#  'ژم\u200cفیبروزیل',
# ...

# %%
length = len(f_generci)
length
# Out:
# 100

# %%
f_generci += ['پروستاگلاندین E1 (آلپروستادیل)',
'ایداروبیسین هیدروکلراید',
'پروستاگلاندین E2',
'لاتانوپروست',
'تریپتورلین (به عنوان استات)',
'ایرینوتکان هیدروکلراید',
'آملودیپین (به عنوان بزیلات)',
'هیدروکورتیزون (به عنوان سدیم سوکسینات)',
'کتوتیفن',
'دیپیریدامول',
'متیل پردنیزولون (به عنوان سدیم سوکسینات)',
'دالتپارین سدیم',
'مزالازین',
'اگزمستان',
'انوکساپارین سدیم',
'فلوپنتیکسول دکانوآت',
'ASA (اسید استیل سالیسیلیک)',
'بروم هگزین هیدروکلراید',
'دیفنهیدرامین / کلرید آمونیوم',
'واکسن آنفولانزا، غیرفعال شده، سه قلو',
'پریمیدون',
'دیکلوفناک سدیم',
'آسیتامینوفن / کدین فسفات',
'آموکسی سیلین',
'کلیندامایسین (به عنوان هیدروکلراید)',
'دیازپام',
'بوسرلین استات',
'اتوسوکسیماید',
'ویتامین B1 (تیامین)',
'کلومیپرامین هیدروکلراید',
'فلوسینولون استونید',
'گادوترات مگلومین',
'کابرگولین',
'سیتالوپرام',
'آکاربوز',
'دیمنهیدرینات',
'استراموستین سدیم فسفات',
'نیمودیپین',
'آمیلورید / هیدروکلروتیازید',
'آتورواستاتین (به عنوان کلسیم)',
'ایماتینیب (به عنوان مزیلات)',
'نیتروفورانتوئین',
'تولترودین تارترات',
'سفیکسیم',
'اُمپرازول',
'سیکلوسپورین',
'استروژن های همپروسانت',
'سفالکسین',
'گلوبولین ایمنی آنتی تتانوس',
'دانوپرازیل هیدروکلراید',
'ریفامپیسین',
'آسیتیل سیستئین',
'پتاسیم لوسارتان',
'فاکتور IX',
'آزیترومایسین',
'منوتروپین',
'تارترات وینورلبین',
'بوپیواکائین هیدروکلراید',
'دکسترومتورفان هیدروبرومید',
'هالوپریدول',
'ویتامین D3',
'کلیندامایسین (به عنوان فسفات)',
'سیمتیدین',
'برومید ایپراتروپیوم',
'هیدرالازین هیدروکلراید',
'سدیم وارفارین',
'آسیکلوویر',
'سیکلوسرین',
'فورموترول فومارات',
'تیوتروپیوم (به عنوان برومید)',
'اینفلیکسیماب',
'لووامیزول',
'تاکرولیموس',
'ممانتین هیدروکلراید',
'کارودیلول',
'سرترالین (به عنوان هیدروکلراید)',
'مبورین هیدروکلراید',
'اندومتاسین',
'فنیتوئین سدیم',
'سولفات وین بلاستین',
'ایزتیمیب',
'ایمونوگلوبولین ضد تیموسوسیت',
'بزیلات آتراکوریوم',
'آلبومین (انسانی)',
'گلوبولین ایمنی هپاتیت B',
'بتاهیستین دی هیدروکلراید',
'تیزانیدین',
'تادالافیل',
'فکسوفنادین هیدروکلراید',
'پانتوپرازول',
'سولفادیازین نقره',
'کلاریترومایسین',
'والسارتان / هیدروکلروتیازید',
'پیپراسیلین (به عنوان سدیم) / تازوباکتام (به عنوان سدیم)',
'تئیکوپلانین',
'ال-کارنیتین',
'اورلیستات',
'هیدروکلرید پتیدین',
'سدیم متوترکسات',
'آنتوسیانوسید']

# %%
length = len(f_generci)
length
# Out:
# 200

# %%
f_generci +=['تترابنازین',
'ایمونوگلوبولین ضد D',
'کلرید استیل کولین',
'پمیدرونات دی سدیم',
'دکستروز',
'میلرینون لاکتات',
'تستوسترون انانتات',
'آلتی پلاز',
'رپاگلینید',
'تریامسینولون آسیتونید',
'کو-آموکسی کلاو',
'فنتانیل (به عنوان سیترات)',
'کمپلکس پروترومبین (غلظت شده)',
'سیس پلاتین',
'نیتروگلیسرین',
'سرتاکونازول نیترات',
'سدیم فلورسیئین',
'انتروفرون بتا-1A',
'فنوفیبرات',
'والسارتان',
'ملوکسیکام',
'آرتیکائین / اپینفرین',
'سفازولین',
'استروژن پروژسترون استات',
'لانزوپرازول',
'پروپیونات کلوبتازول',
'هیوسین بوتیل برومید',
'دروسپیرنون / اتینیل استرادیول',
'پلیاتلن گلیکول - الکترولیت 2',
'واژنیکا - کتاراکت 20٪ (2)',
'دزموپرسین (به عنوان استات)',
'کاربوپلاتین',
'فینگولیمود',
'بودزونید',
'افلوکساسین',
'بنزوکائین',
'سیمتیکون (دی متیکون فعال شده)',
'لیدوکائین هیدروکلراید',
'بلئومایسین',
'پرمترین',
'لووفلوکساسین',
'ریلوزول',
'فاکتور VIIA',
'کلسیتونین، سالمون',
'پرگابالین',
'سورفاکتانت (استخراج گاوی)',
'استرپتوکیناز',
'نیستاتین',
'آسیتامینوفن / کافئین',
'هیدروکلرید تتراسیکلین',
'کلوتریمازول',
'بتامتازون (به عنوان ولرات)',
'ناپروکسن',
'سولفید سلنیم',
'ضد هموروئید',
'لیدوکائین / پریلوکائین',
'کربنات سوولامر',
'آهن (به عنوان سوکروز)',
'دانوروبیسین (به عنوان هیدروکلراید)',
'آسیتامینوفن / کافئین / ASA',
'آدنوزین',
'آلندرونات',
'الفنتانیل',
'آلوپورینول',
'آلپرازولام',
'هیدروکسید آلومینیوم / هیدروکسید منیزیم',
'سیمواستاتین',
'متادون هیدروکلراید',
'گوایفنزین',
'هالوپریدول (به عنوان لاکتات)',
'همودیالیز I',
'همودیالیز غلظت شده III',
'ریباویرین',
'رینجرز',
'ریسپریدون',
'ریواستیگمین (به عنوان تارترات هیدروژن)',
'روپینیرول (به عنوان هیدروکلراید)',
'سالبوتامول (به عنوان سولفات)',
'سالمترول (به عنوان زینافوات)',
'فاموتیدین',
'پسودوافیدرین هیدروکلراید',
'پیریدواستیگمین برومید',
'واکسن خرفا',
'فنول گلیسرین',
'ریزاتریپتان (به عنوان بنزوئات)',
'تاموکسیفن',
'تربینافین',
'تینیدازول',
'یوهیمبین هیدروکلراید',
'زیدووودین',
'اتومیدات',
'همودیالیز II اسیدی',
'اتانول',
'ضد هیستامین - ادونفیکستادین (2)',
'ایمیپنم / سیلاستاتین',
'لیزینوپریل',
'اولانزاپین',
'اوکسکاربازپین',
'سفپیم',
'سلیکوکسیب']

# %%
length = len(f_generci)
length
# Out:
# 300

# %%
f_generci +=['هیدروکلرید ستیریزین',
'ضد بارداری DE',
'استرادیول سیپیونات / استروژن پروژسترون',
'هیدروکلرید متفورمین',
'ایرلوتینیب (به عنوان هیدروکلراید)',
'سالمترول (به عنوان زینافوات) / فلوتیکازون پروپیونات',
'لینزولید',
'مالئات کلروفنیرامین',
'روزوواستاتین (به عنوان کلسیم)',
'دیالیز شکمی II',
'انتروفرون آلفا-2B',
'فریک کاربوکسیمالتوز',
'سفتریاکسون (به عنوان سدیم)',
'والاسیکلوویر',
'آمینو اسید 10٪ پدیاتریک (1)',
'اریترومایسین',
'فلوکونازول',
'فنوباربیتال سدیم',
'محلول‌های سرمان آبرو بزرگسالان (7-23)',
'محلول‌های سرمان آبرو بزرگسالان (7-22)',
'محلول‌های سرمان آبرو بزرگسالان (7-13)',
'محلول‌های سرمان آبرو بزرگسالان (8-1)',
'تریپاراتید',
'دیپروپیونات بکلومتازون',
'فاموتیدین / کربنات کلسیم / هیدروکسید منیزیم',
'هیدروکلرید افلورنیتین',
'سدیم رابپرازول',
'کو-تریموکسازول',
'ضد بارداری HD',
'ضد بارداری LD',
'ضد بارداری سه‌فازی',
'سدیم کرومولین',
'کروتامیتون',
'سایکلوفسفامید',
'استات سیپروترون',
'ترکیب سیپروترون',
'سیتارابین',
'لودوپا / کاربیدوپا فورت',
'هیدروکلراید لووتیروکسین سدیم',
'لیدوکائین / استرادیول هیدروکورتیزون استات',
'لیندان',
'لیوتیرونین سدیم',
'کربنات لیتیم',
'هیدروکلراید لوپرامید',
'لوراتادین',
'لورازپام',
'لوواستاتین',
'لینسترنول',
'هیدروکسید منیزیم',
'سولفات منیزیم',
'مانیتول',
'هیدروکلرید ماپروتیلین',
'واکسن مخصوص خرفا / واکسن مخصوص ماهیان / واکسن مخصوص مخملی',
'مبندازول',
'مزیستین مزیلات دفروکسامین',
'هیدروکلرید دسیپرامین',
'دوبوتامین',
'هیدروکلرید دوپامین',
'دورزولامید (به عنوان هیدروکلراید)',
'دوکسپین',
'دوکسیسیکلین (به عنوان منهیدرات)',
'مالئات انالاپریل',
'اپینفرین',
'هیدروکلرید اپیروبیسین',
'تارترات ارگوتامین / کافئین',
'فیبرینوژن',
'فیناسترید',
'استات فلکاینید',
'استات فلودروکورتیزون',
'هپارین سدیم',
'ویروس هپاتیت B',
'هیدروکلروتیازید',
'هیدروکورتیزون',
'استات هیدروکورتیزون',
'هیدروکینون',
'سولفات هیدروکسیکلروکین',
'کاپروات هیدروکسی پروژسترون',
'هیدروکلرید هیدروکسیزین',
'ایفوسفامید',
'هیدروکلرید ایمیپرامین',
'ایودوکوینول',
'تریفلوپرازین',
'مسنا',
'محلول نمک متعادل (2)',
'سولفات باریم',
'BCG',
'BELLADONNA PB',
'هیدروکلرید بنزیدامین',
'بتامتازون',
'بتامتازون (به عنوان فسفات دی‌سدیم) ',
'بتامتازون LA (بتامتازون به عنوان فسفات دی‌سدیم / بتامتازون استات)',
'هیدروکلراید بیپریدن',
'متیمازول',
'متوکاربامول',
'متوکسالن',
'سالیسیلات متیل',
'متیلدوپا',
'هیدروکلراید متیل‌آرگونووین',
'دینیترات ایزوسورباید',
'ایزوترتینوین']

# %%
length = len(f_generci)
length
# Out:
# 400

# %%
f_generci += ['هیدروکلراید ایزوکسوپرین',
'آیتراکونازول',
'لاکتولوز',
'لامیوودین',
'لاموتریژین',
'لودوپا / کاربیدوپا',
'اسید مفنامیک',
'استات مژسترول',
'اکسید روی',
'آب',
'هیدروکلرید پرومتازین',
'هیدروکلراید وراپامیل',
'ویتامین A',
'ویتامین A / ویتامین D',
'مجموعه ویتامین B',
'ویتامین B12',
'ویتامین B6',
'ویتامین C',
'اسید نالیدیکسیک',
'هیدروکلراید نالترکسون',
'دکانوات ناندرولون',
'نورتریپتیلین',
'آندانسترون',
'اکسالیپلاتین',
'اکسازپام',
'اکسیمتولون',
'اکسیتوسین',
'اسید آمینوبنزوئیک پتاسیم (پوتابا)',
'پانکراتین',
'برمید پانکورونیوم',
'پنی سیلین 6-3-3',
'پنی سیلین G پروکائین',
'پنی سیلین G پتاسیم',
'پنی سیلین V',
'پنی سیلین V پتاسیم',
'پنتوکسیفیلین',
'دیالیز شکمی I',
'فنیتوئین',
'فنیتوئین / فنوباربیتال',
'دیالیز شکمی III',
'پرفنازین',
'فنوباربیتال',
'هیدروکلراید پیلوکارپین',
'پیپرازین',
'پیراسیتام',
'پیروکسیکام',
'هیدروکلراید فنیل‌افرین',
'میزوپروستول',
'پیوگلیتازون',
'زولپیدم',
'پلی‌اتیلن گلیکول',
'دیمتیکون',
'کاربامازپین',
'زولدرونیک اسید',
'لیدوکائین',
'افاویرنز',
'ویتامین B1 / ویتامین B6 / ویتامین B12',
'دومپریدون',
'زونیسامید',
'تنوفوویر دیسوپروکسیل فومارات',
'آملودیپین (به عنوان بزیلات) / آتورواستاتین (به عنوان کلسیم)',
'رانیتیدین',
'بودسونید / فورموترول فومارات',
'انتروفرون بتا-1B',
'آپرپیتانت',
'سیپروفلوکساسین',
'هیدروکلرید لووسیتیریزین',
'سمی‌سدیم والپروات',
'هیدروکلراید پروپرانولول',
'کلرمادینون / اتینیل استرادیول',
'آدفوویر دی‌پیوکسیل',
'سوکسینات متوپرولول',
'آسیتامینوفن / کافئین / ایبوپروفن']

# %%
length = len(f_generci)
length
# Out:
# 473

# %%
length_e = len(e_generic)
length_e
# Out:
# 473

# %%
fa_generic = pd.DataFrame(f_generci)

# %%
fa_generic
# Out:
#                                     0
# 0              استرات متیل پردنیزولون
# 1                      متیل تستوسترون
# 2                        متوکلوپرامید
# 3             هیدروکلرید متوکلوپرامید
# 4                   تارترات متوپرولول
# ..                                ...
# 468           هیدروکلراید پروپرانولول
# 469     کلرمادینون / اتینیل استرادیول
# 470                آدفوویر دی‌پیوکسیل
# 471                سوکسینات متوپرولول
# 472  آسیتامینوفن / کافئین / ایبوپروفن
#
# [473 rows x 1 columns]

# %%
en_generic.columns = ['EnglishGeneric']

# %%
fa_generic.to_excel('fa_generci.xlsx', index =False)

# %%
en_generic.head()
# Out:
#                  EnglishGeneric
# 0    METHYLPREDNISOLONE ACETATE
# 1            METHYLTESTOSTERONE
# 2                METOCLOPRAMIDE
# 3  METOCLOPRAMIDE HYDROCHLORIDE
# 4           METOPROLOL TARTRATE

# %%
fa_generic.columns = ['PersianGeneric']

# %%
fa_generic.head()
# Out:
#             PersianGeneric
# 0   استرات متیل پردنیزولون
# 1           متیل تستوسترون
# 2             متوکلوپرامید
# 3  هیدروکلرید متوکلوپرامید
# 4        تارترات متوپرولول

# %%
generic_name = pd.concat([en_generic, fa_generic], axis=1)

# %%
generic_name
# Out:
#                            EnglishGeneric                    PersianGeneric
# 0              METHYLPREDNISOLONE ACETATE            استرات متیل پردنیزولون
# 1                      METHYLTESTOSTERONE                    متیل تستوسترون
# 2                          METOCLOPRAMIDE                      متوکلوپرامید
# 3            METOCLOPRAMIDE HYDROCHLORIDE           هیدروکلرید متوکلوپرامید
# 4                     METOPROLOL TARTRATE                 تارترات متوپرولول
# ..                                    ...                               ...
# 468             PROPRANOLOL HYDROCHLORIDE           هیدروکلراید پروپرانولول
# 469     CHLORMADINONE / ETHINYL ESTRADIOL     کلرمادینون / اتینیل استرادیول
# 470                    ADEFOVIR DIPIVOXIL                آدفوویر دی‌پیوکسیل
# 471                  METOPROLOL SUCCINATE                سوکسینات متوپرولول
# 472  ACETAMINOPHEN / CAFFEINE / IBUPROFEN  آسیتامینوفن / کافئین / ایبوپروفن
#
# [473 rows x 2 columns]

# %%
generic_name.to_csv('gpt_translated.csv')

# %%
translated = []

for name in drug_shape['GenericName']:
    index = generic_name.loc[generic_name['EnglishGeneric'] == name].index
    translated.append(generic_name['PersianGeneric'][index[0]])

# %%
drug_shape['GenericPersian'] = translated

# %%
drug_shape.head()
# Out:
#             GTIN                                        BrandLaName  \
# 0  6260152433031  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 1  6260157711400  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 2  6260164607277  METHYLPREDNISOLONE ACETATE   INJECTION, SUSPEN...
# 3  6260155200067  DEPOCORTINE   INJECTION, SUSPENSION PARENTERAL...
# 4  6260164645446             METHYLTESTOSTERONE   TABLET ORAL 25 mg
#
#                                            BrandName  NumberPack  \
# 0  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 1  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 2  متیل پردنیزولون استات   سوسپانسیون تزریقی پرنت...           1
# 3  دپوکورتین   سوسپانسیون تزریقی پرنترال 40 mg/1m...           1
# 4                 متیل تستوسترون    قرص خوراکی 25 mg         100
#
#                 Producer  IsBulk                 GenericName  \
# 0             البرز دارو   False  METHYLPREDNISOLONE ACETATE
# ...

# %%
translated
# Out:
# ['استرات متیل پردنیزولون',
#  'استرات متیل پردنیزولون',
#  'استرات متیل پردنیزولون',
#  'استرات متیل پردنیزولون',
#  'متیل تستوسترون',
#  'متوکلوپرامید',
#  'متوکلوپرامید',
#  'متوکلوپرامید',
#  'متوکلوپرامید',
#  'هیدروکلرید متوکلوپرامید',
#  'هیدروکلرید متوکلوپرامید',
#  'هیدروکلرید متوکلوپرامید',
#  'تارترات متوپرولول',
#  'تارترات متوپرولول',
#  'تارترات متوپرولول',
#  'تارترات متوپرولول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'مترونیدازول',
#  'نیترات میکونازول',
#  'میدازولام',
#  'میدازولام',
#  'کلرید سدیم',
#  'کلرید سدیم',
#  'کلرید سدیم',
#  'کلرید سدیم',
#  'کلرید سدیم',
#  'سوربیتول',
#  'سوربیتول',
#  'سوربیتول',
#  'سوربیتول',
#  'هیدروکلرید سوتالول',
#  'هیدروکلرید سوتالول',
#  'اسپایرونولاکتون',
#  'اسپایرونولاکتون',
#  'اسپایرونولاکتون',
#  'استرپتومایسین (به عنوان سولفات)',
#  'سوکسینیل کولین کلرید',
#  'سوکسینیل کولین کلرید',
#  'ساکرالفات',
# ...

# %%
for i,v in zip(drug_shape['GenericName'][:10], translated):
    print(f'{i} --> {v}')
# Out:
# METHYLPREDNISOLONE ACETATE --> استرات متیل پردنیزولون
# METHYLPREDNISOLONE ACETATE --> استرات متیل پردنیزولون
# METHYLPREDNISOLONE ACETATE --> استرات متیل پردنیزولون
# METHYLPREDNISOLONE ACETATE --> استرات متیل پردنیزولون
# METHYLTESTOSTERONE --> متیل تستوسترون
# METOCLOPRAMIDE --> متوکلوپرامید
# METOCLOPRAMIDE --> متوکلوپرامید
# METOCLOPRAMIDE --> متوکلوپرامید
# METOCLOPRAMIDE --> متوکلوپرامید
# METOCLOPRAMIDE HYDROCHLORIDE --> هیدروکلرید متوکلوپرامید
